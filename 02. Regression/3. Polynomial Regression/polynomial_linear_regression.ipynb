# %% [markdown]
# # **Polynomial Linear Regression**
#
# Name: Seanrei Ethan M. Valdeabella
#
# Date: January 11, 2025

# %%
#@title 1. Importing the dataset
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

dataset = pd.read_csv("Position_Salaries.csv")

X = dataset.iloc[:, 1:-1].values
y = dataset.iloc[:, -1].values

# %%
#@title 2. Training the Linear Regression Model on the Whole Dataset
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X, y)
# Out:
# LinearRegression()

# %%
#@title 3. Training the Polynomial Regression Model on the Whole Dataset
from sklearn.preprocessing import PolynomialFeatures
pr = PolynomialFeatures(degree=4)
X_poly = pr.fit_transform(X)
print(X_poly)

lr_2 = LinearRegression()
lr_2.fit(X_poly, y)
# Out:
# [[1.000e+00 1.000e+00 1.000e+00 1.000e+00 1.000e+00]
#  [1.000e+00 2.000e+00 4.000e+00 8.000e+00 1.600e+01]
#  [1.000e+00 3.000e+00 9.000e+00 2.700e+01 8.100e+01]
#  [1.000e+00 4.000e+00 1.600e+01 6.400e+01 2.560e+02]
#  [1.000e+00 5.000e+00 2.500e+01 1.250e+02 6.250e+02]
#  [1.000e+00 6.000e+00 3.600e+01 2.160e+02 1.296e+03]
#  [1.000e+00 7.000e+00 4.900e+01 3.430e+02 2.401e+03]
#  [1.000e+00 8.000e+00 6.400e+01 5.120e+02 4.096e+03]
#  [1.000e+00 9.000e+00 8.100e+01 7.290e+02 6.561e+03]
#  [1.000e+00 1.000e+01 1.000e+02 1.000e+03 1.000e+04]]
# LinearRegression()

# %%
#@title 4. Visualizing the Linear Regression Results
plt.title("Linear Regression Results")
plt.scatter(X, y, color="red")
plt.plot(X, lr.predict(X), color="blue")
plt.xlabel("Position Level")
plt.ylabel("Salary")
plt.show()

# %%
#@title 5. Visualizing the Polynomial Regression Results
plt.title("Polynomial Regression Results")
plt.scatter(X, y, color="red")
plt.plot(X, lr_2.predict(X_poly), color="blue")
plt.xlabel("Position Level")
plt.ylabel("Salary")
plt.show()

# %%
#@title 6. Visualizing the Polynomial Regression Results (for higher resolution and smoother curve)
X_grid = np.arange(min(X), max(X), 0.1)
X_grid = X_grid.reshape(len(X_grid), 1)
plt.scatter(X, y, color="red")
plt.plot(X_grid, lr_2.predict(pr.fit_transform((X_grid))), color="blue")
plt.title("Polynomial Regression")
plt.xlabel("Position Level")
plt.ylabel("Salary")
plt.show()
# Out:
# <ipython-input-93-348aafeedc37>:2: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   X_grid = np.arange(min(X), max(X), 0.1)

# %%
#@title 7. Predicting a New Result with Linear Regression
position_level = 6.5 #@param {type:"number"}


# Prediction
prediction = lr.predict([[position_level]])
print(prediction)
# Out:
# [330378.78787879]

# %%
#@title 8. Predicting a New Result with Polynomial Regression
position_level = 6.5 #@param {type:"number"}
lr_2.predict(pr.fit_transform([[position_level]]))
# Out:
# array([158862.45265155])
